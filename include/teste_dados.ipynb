# %%
# !pip install -q pandas numpy gdown pyspark

# %%
import pandas as pd
import numpy as np

# %%
import gdown

file_id = "1Vumu8jo3P3umuUtBZb6mn7YoVIo4X0ON"  # ID do arquivo
output_path = "./dados.csv"  # Ajuste o nome e formato do arquivo conforme necessário
url = f"https://drive.google.com/uc?id={file_id}"
gdown.download(url, output_path, quiet=False)
print(f"Arquivo baixado em: {output_path}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Vumu8jo3P3umuUtBZb6mn7YoVIo4X0ON
# From (redirected): https://drive.google.com/uc?id=1Vumu8jo3P3umuUtBZb6mn7YoVIo4X0ON&confirm=t&uuid=ec157fe2-3ea3-4cc4-ab6a-f967fde88cbb
# To: c:\Users\thiag\Desktop\TarefaLocaliza\include\dados.csv
# 100%|██████████| 1.55G/1.55G [00:31<00:00, 48.9MB/s]
# Arquivo baixado em: ./dados.csv

# %%
dataframe = pd.read_csv("./dados.csv", sep=',')

# %%
dataframe
# Out:
#           timestamp                             sending_address  \
# 0        1618185002  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1        1698642474  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2        1619180066  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3        1591413882  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4        1611257295  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
# ...             ...                                         ...
# 9291889  1595927781  0x3eb68b3538b68085f25e2b0f3b8f1d2061399b50
# 9291890  1681555766  0x617b83371b4c65debb6c2e90de89c827ddcb0884
# 9291891  1687293025  0x9e93530df033899e6334d6941e67a24f7ba6c5ea
# 9291892  1646891835  0xcd6c7bd7ed48fe825845ff6ca3a8e9ae599dbc15
# 9291893  1608299418  0xbd9407cd80008ab4ef633025b88e403af9e01386
#
#                                   receiving_address   amount transaction_type  \
# 0        0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# ...

# %%
from pyspark.sql import SparkSession

# Inicialize o SparkSession
spark = SparkSession.builder.appName("CSVDataProcessing").getOrCreate()

# Defina o caminho do arquivo CSV (ajuste o caminho conforme necessário)
csv_file_path = './dados.csv'

# Leitura do CSV no DataFrame
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Mostrar as primeiras linhas do DataFrame
df.show()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[30], line 4
#       1 from pyspark.sql import SparkSession
#       3 # Inicialize o SparkSession
# ----> 4 spark = SparkSession.builder .appName("CSVDataProcessing").getOrCreate()
#       6 # Defina o caminho do arquivo CSV (ajuste o caminho conforme necessário)
#       7 csv_file_path = './dados.csv'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...

# %%
erros
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dataframe.map(np.isreal)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:10468, in DataFrame.map(self, func, na_action, **kwargs)
#   10465 def infer(x):
#   10466     return x._map_values(func, na_action=na_action)
# > 10468 return self.apply(infer).__finalize__(self, "map")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
# ...
